# %%
! pip install pandas numpy

# %%
import pandas as pd
import numpy as np
from table1 import table1
from inital_clean import (cleaning, add_columns, filter_otm_atm)
from forward_price import estimate_forward_curve

# %%
data = pd.read_csv("dissertation_data.csv")

# %%
forward_data = estimate_forward_curve(data)

# %%
forward_data.info()

# %%
data.info()

# %%
forward_data.head()

# %%
data.to_csv("cleaned_2000-2025.csv", index = False)

# %%
forward_data.to_csv("forward_data_2000-2025.csv", index = False)

# %%
filtered = filter_otm_atm(data,forward_data)
